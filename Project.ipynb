# %% [markdown]
# **FOR READ PDF FILE HERE**

# %%
import tabula
import pandas as pd

# %%
df = tabula.read_pdf("dataset.pdf",pages="all")
df
# Out:
# [    S. No.                      State                District  \
#  0        1  Andaman & Nicobar Islands  North & Middle Andaman
#  1        2  Andaman & Nicobar Islands  North & Middle Andaman
#  2        3  Andaman & Nicobar Islands  North & Middle Andaman
#  3        4  Andaman & Nicobar Islands  North & Middle Andaman
#  4        5  Andaman & Nicobar Islands  North & Middle Andaman
#  ..     ...                        ...                     ...
#  79      80  Andaman & Nicobar Islands           South Andaman
#  80      81  Andaman & Nicobar Islands           South Andaman
#  81      82  Andaman & Nicobar Islands           South Andaman
#  82      83  Andaman & Nicobar Islands           South Andaman
#  83      84  Andaman & Nicobar Islands           South Andaman
#
#                  Unnamed: 0  Location Longitude  Latitude  Year    pH  \
#  0                Bakultala       NaN   92.8577   12.5043  2023  7.96
# ...

# %% [markdown]
# **FOR CONVERT INTO CSV FORMAT**

# %%
tabula.convert_into("dataset.pdf", "dataset.csv", pages="all", output_format="csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tabula.convert_into("dataset.pdf", "dataset.csv", pages="all", output_format="csv")
#
# File E:\Lib\site-packages\tabula\io.py:835, in convert_into(input_path, output_path, output_format, java_options, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, force_subprocess, options)
#     832     raise ValueError(f"{path} is empty. Check the file, or download it manually.")
#     834 try:
# --> 835     _run(tabula_options, java_options, path, force_subprocess=force_subprocess)
#     836 finally:
#     837     if temporary:
#
# File E:\Lib\site-packages\tabula\io.py:86, in _run(options, java_options, path, encoding, force_subprocess)
#      83 elif set(java_options) - IGNORED_JAVA_OPTIONS:
# ...

# %%
tabula.convert_into("datasetpages.pdf", "datasetpages.csv", pages="all", output_format="csv")

# %%
import pandas as pd 
df = pd.read_csv("C:\\jn\\datasetmain.csv", on_bad_lines='skip')
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("C:\\jn\\datasetmain.csv", on_bad_lines='skip')
#       3 df
#
# File E:\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# **FOR READ CSV FILE**

# %%
import pandas as pd
fd= pd.read_csv("datasetmain.csv", delimiter=",", encoding="ISO-8859-1")
fd
# Out:
#        S. No.                      State                District  \
# 0           1  Andaman & Nicobar Islands  North & Middle Andaman
# 1           2  Andaman & Nicobar Islands  North & Middle Andaman
# 2           3  Andaman & Nicobar Islands  North & Middle Andaman
# 3           4  Andaman & Nicobar Islands  North & Middle Andaman
# 4           5  Andaman & Nicobar Islands  North & Middle Andaman
# ...       ...                        ...                     ...
# 16771   16772                     Odisha                 SONAPUR
# 16772   16773                     Odisha                 SONAPUR
# 16773   16774                     Odisha                 SONAPUR
# 16774   16775                     Odisha                 SONAPUR
# 16775   16776                     Odisha                 SONAPUR
#
#                      Location Longitude  Latitude  Year    pH EC (µS/cm at  \
# 0                   Bakultala   92.8577   12.5043  2023  7.96          395
# ...
