# %%
import pandas as pd

# %%
# df = pd.read_csv("datasetmain.csv", delimiter=",", encoding="utf-8")
# df
df= pd.read_csv("datasetmain.csv", delimiter=",", encoding="ISO-8859-1")
df
# Out:
#        S. No.                      State                District  \
# 0           1  Andaman & Nicobar Islands  North & Middle Andaman
# 1           2  Andaman & Nicobar Islands  North & Middle Andaman
# 2           3  Andaman & Nicobar Islands  North & Middle Andaman
# 3           4  Andaman & Nicobar Islands  North & Middle Andaman
# 4           5  Andaman & Nicobar Islands  North & Middle Andaman
# ...       ...                        ...                     ...
# 16771   16772                     Odisha                 SONAPUR
# 16772   16773                     Odisha                 SONAPUR
# 16773   16774                     Odisha                 SONAPUR
# 16774   16775                     Odisha                 SONAPUR
# 16775   16776                     Odisha                 SONAPUR
#
#                      Location Longitude  Latitude  Year    pH EC (µS/cm at)  \
# 0                   Bakultala   92.8577   12.5043  2023  7.96           395
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16776 entries, 0 to 16775
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S. No.          16776 non-null  int64
#  1   State           16776 non-null  object
#  2   District        16776 non-null  object
#  3   Location        16745 non-null  object
#  4   Longitude       16774 non-null  object
#  5   Latitude        16773 non-null  object
#  6   Year            16776 non-null  int64
#  7   pH              16776 non-null  object
#  8   EC (µS/cm at)   16776 non-null  object
#  9   CO3 (mg/L)      16776 non-null  object
#  10  HCO3            16776 non-null  object
#  11  Cl (mg/L)       16776 non-null  object
#  12  F (mg/L)        16776 non-null  object
#  13  SO4             16776 non-null  object
#  14  NO3             16776 non-null  object
#  15  PO4             16776 non-null  object
#  16  Total Hardness  16776 non-null  object
# ...

# %%
print(df.describe())
# Out:
#              S. No.     Year
# count  16776.000000  16776.0
# mean    8388.500000   2023.0
# std     4842.958393      0.0
# min        1.000000   2023.0
# 25%     4194.750000   2023.0
# 50%     8388.500000   2023.0
# 75%    12582.250000   2023.0
# max    16776.000000   2023.0

# %%
df.isnull().sum()
# Out:
# S. No.             0
# State              0
# District           0
# Location          31
# Longitude          2
# Latitude           3
# Year               0
# pH                 0
# EC (µS/cm at)      0
# CO3 (mg/L)         0
# HCO3               0
# Cl (mg/L)          0
# F (mg/L)           0
# SO4                0
# NO3                0
# PO4                0
# Total Hardness     0
# Ca (mg/L)          0
# Mg (mg/L)          0
# Na (mg/L)          0
# K (mg/L)           0
# Fe (ppm)           0
# As (ppb)           0
# U (ppb)            0
# dtype: int64

# %%
# df= pd.read_csv("datasetmain12.csv")
# zero_counts = (df == 0).sum()
# most_zeros_column = zero_counts.idxmax()
# most_zeros_count = zero_counts.max()

# print(f"Column with most zeros: {most_zeros_column}, Count: {most_zeros_count}")

# %% [markdown]
# Now remove the CO3 (mg/L) from the dataset. By storing the whole dataset in other variable than the previous one(df) named, data_without_CO3.

# %%
data_without_CO3 = df[['S. No.', 'State', 'District', 'Location', 'Longitude', 'Latitude', 'Year', 'pH', 'EC (µS/cm at)', 'HCO3', 'Cl (mg/L)', 'F (mg/L)', 'SO4', 'NO3', 'PO4', 'Total Hardness', 'Ca (mg/L)', 'Mg (mg/L)', 'Na (mg/L)','K (mg/L)', 'Fe (ppm)','As (ppb)', 'U (ppb)']]
data_without_CO3
# Out:
#        S. No.                      State                District  \
# 0           1  Andaman & Nicobar Islands  North & Middle Andaman
# 1           2  Andaman & Nicobar Islands  North & Middle Andaman
# 2           3  Andaman & Nicobar Islands  North & Middle Andaman
# 3           4  Andaman & Nicobar Islands  North & Middle Andaman
# 4           5  Andaman & Nicobar Islands  North & Middle Andaman
# ...       ...                        ...                     ...
# 16771   16772                     Odisha                 SONAPUR
# 16772   16773                     Odisha                 SONAPUR
# 16773   16774                     Odisha                 SONAPUR
# 16774   16775                     Odisha                 SONAPUR
# 16775   16776                     Odisha                 SONAPUR
#
#                      Location Longitude  Latitude  Year    pH EC (µS/cm at)  \
# 0                   Bakultala   92.8577   12.5043  2023  7.96           395
# ...

# %%
data_without_CO3
# Out:
#        S. No.                      State                District  \
# 0           1  Andaman & Nicobar Islands  North & Middle Andaman
# 1           2  Andaman & Nicobar Islands  North & Middle Andaman
# 2           3  Andaman & Nicobar Islands  North & Middle Andaman
# 3           4  Andaman & Nicobar Islands  North & Middle Andaman
# 4           5  Andaman & Nicobar Islands  North & Middle Andaman
# ...       ...                        ...                     ...
# 16771   16772                     Odisha                 SONAPUR
# 16772   16773                     Odisha                 SONAPUR
# 16773   16774                     Odisha                 SONAPUR
# 16774   16775                     Odisha                 SONAPUR
# 16775   16776                     Odisha                 SONAPUR
#
#                      Location Longitude  Latitude  Year    pH EC (µS/cm at)  \
# 0                   Bakultala   92.8577   12.5043  2023  7.96           395
# ...

# %% [markdown]
# Storing all states in other variables

# %%
ANI = data_without_CO3[data_without_CO3["State"] == "Andaman & Nicobar Islands"]
ANI
# Out:
#      S. No.                      State                District  \
# 0         1  Andaman & Nicobar Islands  North & Middle Andaman
# 1         2  Andaman & Nicobar Islands  North & Middle Andaman
# 2         3  Andaman & Nicobar Islands  North & Middle Andaman
# 3         4  Andaman & Nicobar Islands  North & Middle Andaman
# 4         5  Andaman & Nicobar Islands  North & Middle Andaman
# ..      ...                        ...                     ...
# 108     109  Andaman & Nicobar Islands           South Andaman
# 109     110  Andaman & Nicobar Islands           South Andaman
# 110     111  Andaman & Nicobar Islands           South Andaman
# 111     112  Andaman & Nicobar Islands           South Andaman
# 112     113  Andaman & Nicobar Islands           South Andaman
#
#                    Location Longitude Latitude  Year    pH EC (µS/cm at) HCO3  \
# 0                 Bakultala   92.8577  12.5043  2023  7.96           395  171
# ...

# %%
AP = data_without_CO3[data_without_CO3["State"] == "Arunachal Pradesh"]
AP
# Out:
#      S. No.              State    District           Location Longitude  \
# 113     114  Arunachal Pradesh   Changlang          Jairampur   96.0144
# 114     115  Arunachal Pradesh   Changlang            Namchik    95.972
# 115     116  Arunachal Pradesh   Changlang            Namphai   96.1086
# 116     117  Arunachal Pradesh   Changlang  Newlisan Kharsang   96.0418
# 117     118  Arunachal Pradesh  East Siang       Pasighat New   95.3358
# 118     119  Arunachal Pradesh  East Siang               Oyan   95.3183
# 119     120  Arunachal Pradesh  East Siang             Ruksin   95.2182
# 5253    5254  Maharashtra    Yavatmal      Wadgaon   78.1167  20.3833  2023
# 5254    5255  Maharashtra    Yavatmal     Yavatmal   78.1167  20.3911  2023
#
# ...

# %%
Megha = data_without_CO3[data_without_CO3["State"]=="Meghalaya"]
Megha
# Out:
#       S. No.      State              District                Location  \
# 5255    5256  Meghalaya       East Garo Hills             Narringirri
# 5256    5257  Meghalaya       East Garo Hills       Samanda Megapagre
# 5257    5258  Meghalaya       East Garo Hills           William Nagar
# 5258    5259  Meghalaya       East Garo Hills                 Songsak
# 5259    5260  Meghalaya      East Khasi Hills                  Dangar
# 5260    5261  Meghalaya      East Khasi Hills                Mawkynep
# 5261    5262  Meghalaya      East Khasi Hills               Mawsynram
# 5262    5263  Meghalaya      East Khasi Hills                  Tyrsad
# 5263    5264  Meghalaya      East Khasi Hills               Jail Road
# 5264    5265  Meghalaya      East Khasi Hills                Lapalang
# 5265    5266  Meghalaya      East Khasi Hills          Lr.Lachaumiere
# 5266    5267  Meghalaya      East Khasi Hills     Shillong Golf Links
# ...

# %%
Mizo = data_without_CO3[data_without_CO3["State"]=="Mizoram"]
Mizo
# Out:
#       S. No.    State  District     Location Longitude Latitude  Year    pH  \
# 5294    5295  Mizoram   Kolasib  Tuichhuahen   92.6811  24.2575  2023  8.05
# 5295    5296  Mizoram     Mamit      Zawlnum    92.335  24.1389  2023  7.67
# 5296    5297  Mizoram  Serchhip     Thenzawl   92.7733  23.2811  2023  7.85
#
#      EC (µS/cm at) HCO3  ... NO3 PO4 Total Hardness Ca (mg/L) Mg (mg/L)  \
# 5294           371  275  ...   1   -            200        12        41
# 5295           405   61  ...   4   -            115        32         8
# 5296            76   31  ...   4   -             35         8         4
#
#      Na (mg/L) K (mg/L) Fe (ppm) As (ppb) U (ppb)
# 5294        13        8     0.12     0.03    0.08
# 5295        39        3     0.04     0.55     0.7
# 5296         4        1     0.25     0.06    0.02
#
# [3 rows x 23 columns]

# %%
Naga = data_without_CO3[data_without_CO3["State"]=="Nagaland"]
Naga
# Out:
#       S. No.     State District         Location Longitude Latitude  Year  \
# 5297    5298  Nagaland  Dimapur  7Th Mile Colony   93.7742  25.8439  2023
# 5298    5299  Nagaland  Dimapur       Chumkidima   93.7831  25.8169  2023
# 5299    5300  Nagaland  Dimapur         Diphupar   93.7733  25.8644  2023
# 5300    5301  Nagaland  Dimapur      Douapur Dmc   93.6044  25.7611  2023
# 5301    5302  Nagaland  Dimapur         Maibiram   93.6195  25.7736  2023
# 5302    5303  Nagaland  Dimapur   Marwari Colony   93.7254  25.9056  2023
#
#         pH EC (µS/cm at) HCO3  ... NO3 PO4 Total Hardness Ca (mg/L) Mg (mg/L)  \
# 5297  7.52           339   18  ...  43   -            105        36         4
# 5298  6.75           418  122  ...   2   -            130        34        11
# 5299  7.84           481   43  ...  26   -            105        24        11
# 5300  6.49           154   37  ...   6   -             65        18         5
# ...

# %%
Odi = data_without_CO3[data_without_CO3["State"]=="Odisha"]
Odi
# Out:
#        S. No.   State District     Location Longitude  Latitude  Year    pH  \
# 15867   15868  Madhya Pradesh       Sidhi       Matehani   24.4409  82.1319
# 15868   15869  Madhya Pradesh       Sidhi       Chagohar   23.9886  81.9381
# 15869   15870  Madhya Pradesh     Vidisha     Lateri New   24.0583  77.4057
# 15870   15871  Madhya Pradesh        Guna     Chetabarri    24.431  77.1545
# 15871   15872  Madhya Pradesh       Betul          Thani   21.6557   77.923
#
# ...

# %% [markdown]
# One by One State analysis
# 1. Andaman & Nicobar Islands
#  - In the dataset we have so many entries with "-" so replace them with "Nan" as in Null values. To make things easier.

# %%
import numpy as np
from scipy.stats import skew
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as  px
ANI = ANI.replace("-", np.nan)
ANI
# Out:
# C:\Users\Eti Garg\AppData\Local\Temp\ipykernel_8908\2012350032.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ANI = ANI.replace("-", np.nan)
#      S. No.                      State                District  \
# 0         1  Andaman & Nicobar Islands  North & Middle Andaman
# 1         2  Andaman & Nicobar Islands  North & Middle Andaman
# 2         3  Andaman & Nicobar Islands  North & Middle Andaman
# 3         4  Andaman & Nicobar Islands  North & Middle Andaman
# 4         5  Andaman & Nicobar Islands  North & Middle Andaman
# ..      ...                        ...                     ...
# 108     109  Andaman & Nicobar Islands           South Andaman
# 109     110  Andaman & Nicobar Islands           South Andaman
# ...

# %%
ANI.isnull().sum()
# Out:
# S. No.              0
# State               0
# District            0
# Location            0
# Longitude           0
# Latitude            0
# Year                0
# pH                  0
# EC (µS/cm at)       0
# HCO3                0
# Cl (mg/L)           0
# F (mg/L)            0
# SO4                 0
# NO3                 0
# PO4                 0
# Total Hardness      0
# Ca (mg/L)           0
# Mg (mg/L)           0
# Na (mg/L)           0
# K (mg/L)            0
# Fe (ppm)            0
# As (ppb)          113
# U (ppb)           113
# dtype: int64

# %%
ANI=ANI.drop("As (ppb)", axis=1)
ANI.head()
# Out:
#    S. No.                      State                District  \
# 0       1  Andaman & Nicobar Islands  North & Middle Andaman
# 1       2  Andaman & Nicobar Islands  North & Middle Andaman
# 2       3  Andaman & Nicobar Islands  North & Middle Andaman
# 3       4  Andaman & Nicobar Islands  North & Middle Andaman
# 4       5  Andaman & Nicobar Islands  North & Middle Andaman
#
#                  Location Longitude Latitude  Year    pH EC (µS/cm at) HCO3  \
# 0               Bakultala   92.8577  12.5043  2023  7.96           395  171
# 1     Baratang (Nilambur)    92.767  12.1683  2023  8.19           473   31
# 2              Basantipur   92.8737  12.7579  2023  8.19           556  220
# 3                 Betapur   92.9434  12.6191  2023  8.07           487  214
# 4  Dhobidera (Mayabunder)   92.8992  12.9099  2023  8.02           567  232
#
#    ... SO4 NO3   PO4 Total Hardness Ca (mg/L) Mg (mg/L) Na (mg/L) K (mg/L)  \
# ...

# %%
ANI=ANI.drop("U (ppb)", axis=1)
ANI.head()
# Out:
#    S. No.                      State                District  \
# 0       1  Andaman & Nicobar Islands  North & Middle Andaman
# 1       2  Andaman & Nicobar Islands  North & Middle Andaman
# 2       3  Andaman & Nicobar Islands  North & Middle Andaman
# 3       4  Andaman & Nicobar Islands  North & Middle Andaman
# 4       5  Andaman & Nicobar Islands  North & Middle Andaman
#
#                  Location Longitude Latitude  Year    pH EC (µS/cm at) HCO3  \
# 0               Bakultala   92.8577  12.5043  2023  7.96           395  171
# 1     Baratang (Nilambur)    92.767  12.1683  2023  8.19           473   31
# 2              Basantipur   92.8737  12.7579  2023  8.19           556  220
# 3                 Betapur   92.9434  12.6191  2023  8.07           487  214
# 4  Dhobidera (Mayabunder)   92.8992  12.9099  2023  8.02           567  232
#
#    ... F (mg/L) SO4 NO3   PO4 Total Hardness Ca (mg/L) Mg (mg/L) Na (mg/L)  \
# ...

# %%
ANI.isnull().sum()
# Out:
# S. No.            0
# State             0
# District          0
# Location          0
# Longitude         0
# Latitude          0
# Year              0
# pH                0
# EC (µS/cm at)     0
# HCO3              0
# Cl (mg/L)         0
# F (mg/L)          0
# SO4               0
# NO3               0
# PO4               0
# Total Hardness    0
# Ca (mg/L)         0
# Mg (mg/L)         0
# Na (mg/L)         0
# K (mg/L)          0
# Fe (ppm)          0
# dtype: int64

# %% [markdown]
# NO null values in the Arunachal Pradesh's dataframe

# %%
# ANI.head()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# from scipy.stats import skew
#

# %%
ANI_num = ANI[[ 'pH', 'EC (µS/cm at)', 'HCO3', 'Cl (mg/L)', 'F (mg/L)', 'SO4', 'NO3', 'PO4', 'Total Hardness', 'Ca (mg/L)', 'Mg (mg/L)', 'Na (mg/L)','K (mg/L)', 'Fe (ppm)']]
ANI_num #store only columns with numerical values
# Out:
#        pH EC (µS/cm at) HCO3 Cl (mg/L) F (mg/L)  SO4 NO3   PO4 Total Hardness  \
# 0    7.96           395  171        14     0.18   28   8  0.04            160
# 1    8.19           473   31        96        0   50  10  0.03            135
# 2    8.19           556  220        28        0   51   1  0.05            230
# 3    8.07           487  214        57     0.16    0   2  0.08             95
# 4    8.02           567  232        39     0.13   29  11  0.04            230
# ..    ...           ...  ...       ...      ...  ...  ..   ...            ...
# 108  8.22           838  104        53      0.3  231  14  0.05            200
# 109  8.03           539  140       103        0    0   5  0.02            155
# 110   8.3          1910  695       245     0.34   42  12  0.01            365
# 111     8           451  214        18     0.09   28   1     0            165
# 112  8.21            75   18         7        0    9   1   0.1             15
#
# ...

# %%
# numeric_cols = ANI_num.select_dtypes(include=['int64', 'float64'])
# mean_values = numeric_cols.mean("pH")
# mean_values

# %%
# skewness = ANI_skew.skew()

# # Plot skewness distribution as a bar plot
# plt.figure(figsize=(10, 5))
# sns.barplot(x=skewness.index, y=skewness.values, palette="coolwarm")

# # Add labels and title
# plt.axhline(0, color="black", linestyle="--", linewidth=1)  # Reference line at 0
# plt.xticks(rotation=45)  # Rotate x-axis labels for readability
# plt.ylabel("Skewness Value")
# plt.xlabel("Features")
# plt.title("Skewness Distribution of Dataset")
# plt.show()

# %% [markdown]
# Checking the numerical data of ANI for nulll values
# - if pink then no null values

# %%
plt.figure(figsize=(4,3))
sns.heatmap(ANI_num.isnull())
# Out:
# <Axes: >

# %%
# fd = pd.DataFrame(ANI_num)
# fd["pH"] = pd.to_numeric(fd["pH"], errors="coerce")
# fd.dtypes
fd = pd.DataFrame(ANI_num)
to_convert = [
    "pH", "EC (µS/cm at)", "Ca (mg/L)", "Cl (mg/L)", "F (mg/L)", "Fe (ppm)", "HCO3", "K (mg/L)",
    "Mg (mg/L)", "NO3", "Na (mg/L)", "PO4", "SO4", "Total Hardness"
]
for col in to_convert:
    fd[col] = pd.to_numeric(fd[col], errors="coerce")
print(fd.dtypes)
# Out:
# pH                float64
# EC (µS/cm at)       int64
# HCO3                int64
# Cl (mg/L)           int64
# F (mg/L)          float64
# SO4                 int64
# NO3                 int64
# PO4               float64
# Total Hardness      int64
# Ca (mg/L)           int64
# Mg (mg/L)           int64
# Na (mg/L)           int64
# K (mg/L)            int64
# Fe (ppm)          float64
# dtype: object

# %%
mean_values =  [fd[col].mean() for col in to_convert]
mean_values
# Out:
# [np.float64(8.108318584070798),
#  np.float64(499.42477876106193),
#  np.float64(23.716814159292035),
#  np.float64(52.34513274336283),
#  np.float64(0.1370796460176991),
#  np.float64(0.5875221238938054),
#  np.float64(185.9203539823009),
#  np.float64(3.5575221238938055),
#  np.float64(25.451327433628318),
#  np.float64(4.504424778761062),
#  np.float64(40.575221238938056),
#  np.float64(0.0404424778761062),
#  np.float64(25.858407079646017),
#  np.float64(163.93805309734512)]

# %%
skewness_values = {col: skew(fd[col].dropna()) for col in to_convert}
skewness_values
# Out:
# {'pH': np.float64(-1.0568968033957469),
#  'EC (µS/cm at)': np.float64(3.1353714667308394),
#  'Ca (mg/L)': np.float64(1.3845949365330277),
#  'Cl (mg/L)': np.float64(5.383999488020173),
#  'F (mg/L)': np.float64(1.2592433384666553),
#  'Fe (ppm)': np.float64(3.8211999811711204),
#  'HCO3': np.float64(1.589880995344346),
#  'K (mg/L)': np.float64(3.95238877238842),
#  'Mg (mg/L)': np.float64(0.6491583537586104),
#  'NO3': np.float64(2.7309874355840544),
#  'Na (mg/L)': np.float64(3.9841151025710784),
#  'PO4': np.float64(0.3025202309968829),
#  'SO4': np.float64(3.9660119311509603),
#  'Total Hardness': np.float64(0.6474492078966663)}

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# fd[to_convert] = scaler.fit_transform(fd[to_convert])
# fd

# %%
plt.figure()
sns.displot(fd)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.kdeplot(skewness_values, fill=True)
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method="yeo-johnson")  # Auto-adjusts transformation
fd[to_convert] = pt.fit_transform(fd[to_convert])
fd
# Out:
#            pH  EC (µS/cm at)      HCO3  Cl (mg/L)  F (mg/L)       SO4  \
# 0   -1.191034      -0.149755  0.022768  -1.428459  0.687282  0.530214
# 1    0.569412       0.175180 -2.143797   1.269825 -1.085666  1.071604
# 2    0.569412       0.468745  0.483613  -0.266349 -1.085666  1.091151
# 3   -0.495189       0.228001  0.430804   0.694911  0.562728 -1.824111
# 4   -0.839579       0.504450  0.586645   0.209098  0.350647  0.561303
# ..        ...            ...       ...        ...       ...       ...
# 108  0.898824       1.222389 -0.764136   0.606390  1.227703  2.804351
# 109 -0.774698       0.412209 -0.312214   1.339954 -1.085666 -1.824111
# 110  1.930138       2.773744  3.266829   2.077312  1.351009  0.902550
# 111 -0.963732       0.089067  0.430804  -0.980156  0.011335  0.530214
# 112  0.785829      -3.028789 -2.576012  -2.820983 -1.085666 -0.361641
#
#           NO3       PO4  Total Hardness  Ca (mg/L)  Mg (mg/L)  Na (mg/L)  \
# ...

# %%
m_val_ani_after_scaling = [fd[col].mean() for col in to_convert]
m_val_ani_after_scaling
# Out:
# [np.float64(-2.525020507333321e-16),
#  np.float64(1.1161180141364405e-15),
#  np.float64(7.624186434593995e-16),
#  np.float64(7.663486364669222e-16),
#  np.float64(6.877487763164686e-17),
#  np.float64(-1.0021482169182829e-16),
#  np.float64(-1.5719972030090712e-16),
#  np.float64(3.4436563728417467e-16),
#  np.float64(1.0610981120311231e-16),
#  np.float64(-1.3607600788547273e-16),
#  np.float64(3.9496429725602916e-16),
#  np.float64(-2.947494755642009e-17),
#  np.float64(4.961616171997381e-17),
#  np.float64(3.340494056394276e-16)]

# %%
sk_val_ani_after_scaling = {col: skew(fd[col].dropna()) for col in to_convert}
sk_val_ani_after_scaling
# Out:
# {'pH': np.float64(-0.10640785760547951),
#  'EC (µS/cm at)': np.float64(0.012781003679232383),
#  'Ca (mg/L)': np.float64(0.019373726400889996),
#  'Cl (mg/L)': np.float64(0.0013386700291781952),
#  'F (mg/L)': np.float64(0.3203653396294973),
#  'Fe (ppm)': np.float64(0.6624476918242955),
#  'HCO3': np.float64(0.04539290917963019),
#  'K (mg/L)': np.float64(0.0032103773898111178),
#  'Mg (mg/L)': np.float64(-0.08123079133039393),
#  'NO3': np.float64(0.0833290422470428),
#  'Na (mg/L)': np.float64(0.014298535327011756),
#  'PO4': np.float64(0.09273838910774186),
#  'SO4': np.float64(0.013762329393805882),
#  'Total Hardness': np.float64(0.003704118523107915)}

# %%
plt.figure()
sns.displot(sk_val_ani_after_scaling)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(sk_val_ani_after_scaling, fill=True)
plt.show()

# %%
# import numpy as np
# fd[to_convert] = np.sqrt(fd[to_convert])

# %%
# from scipy.stats import boxcox
# for col in to_convert:
#     fd[col], lambda_ = boxcox(fd[col].values)
    # fd[to_convert], lambda_ = boxcox(fd[to_convert].squeeze())

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method="yeo-johnson")  # Auto-adjusts transformation
fd[to_convert] = pt.fit_transform(fd[to_convert])
fd
# pt = PowerTransformer(method="yeo-johnson")  # Default is "yeo-johnson"
# fd[to_convert] = pt.fit_transform(fd[[to_convert]])
# Out:
#            pH  EC (µS/cm at)      HCO3  Cl (mg/L)  F (mg/L)       SO4  \
# 0   -1.180724      -0.147527  0.020310  -1.440182  0.763040  0.520267
# 1    0.553696       0.177383 -2.135778   1.262692 -1.147167  1.075961
# 2    0.553696       0.470390  0.481868  -0.256655 -1.147167  1.096158
# 3   -0.514474       0.230138  0.428919   0.699582  0.656632 -1.790960
# 4   -0.846543       0.505998  0.585215   0.219183  0.468224  0.551966
# ..        ...            ...       ...        ...       ...       ...
# 108  0.897003       1.220901 -0.764874   0.612402  1.195826  2.892851
# 109 -0.784360       0.413996 -0.314347   1.331058 -1.147167 -1.790960
# 110  1.997809       2.760702  3.285317   2.046417  1.289096  0.901652
# 111 -0.965088       0.091343  0.428919  -0.980942  0.143085  0.520267
# 112  0.778707      -3.044357 -2.564244  -2.881672 -1.147167 -0.374420
#
#           NO3       PO4  Total Hardness  Ca (mg/L)  Mg (mg/L)  Na (mg/L)  \
# ...

# %%
m_val_ani_after_scaling = [fd[col].mean() for col in to_convert]
m_val_ani_after_scaling
# Out:
# [np.float64(-1.964996503761339e-17),
#  np.float64(-3.1439944060181424e-17),
#  np.float64(-1.964996503761339e-17),
#  np.float64(-1.5719972030090712e-17),
#  np.float64(1.768496853385205e-17),
#  np.float64(1.3754975526329373e-17),
#  np.float64(3.929993007522678e-17),
#  np.float64(-2.8492449304539417e-17),
#  np.float64(2.3579958045136068e-17),
#  np.float64(3.094869493424109e-17),
#  np.float64(-3.929993007522678e-17),
#  np.float64(-2.5544954548897407e-17),
#  np.float64(-4.421242133463013e-18),
#  np.float64(-3.929993007522678e-18)]

# %%
sk_val_ani_after_scaling = {col: skew(fd[col].dropna()) for col in to_convert}
sk_val_ani_after_scaling
# Out:
# {'pH': np.float64(-0.018870586017619102),
#  'EC (µS/cm at)': np.float64(-0.009683447994998439),
#  'Ca (mg/L)': np.float64(0.02435653945834344),
#  'Cl (mg/L)': np.float64(-0.058854440774403105),
#  'F (mg/L)': np.float64(0.11632232614430675),
#  'Fe (ppm)': np.float64(0.186713119291645),
#  'HCO3': np.float64(0.06338260705707247),
#  'K (mg/L)': np.float64(0.004424060449042807),
#  'Mg (mg/L)': np.float64(0.031038600864967788),
#  'NO3': np.float64(0.029954796954177156),
#  'Na (mg/L)': np.float64(-0.03639571666347547),
#  'PO4': np.float64(0.03779592451688518),
#  'SO4': np.float64(0.11607309900961846),
#  'Total Hardness': np.float64(0.07685894903340011)}

# %%
plt.figure()
sns.displot(sk_val_ani_after_scaling)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(sk_val_ani_after_scaling, fill=True)
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method="yeo-johnson")  # Auto-adjusts transformation
fd[to_convert] = pt.fit_transform(fd[to_convert])
fd
# Out:
#            pH  EC (µS/cm at)      HCO3  Cl (mg/L)  F (mg/L)       SO4  \
# 0   -1.179485      -0.147758  0.020462  -1.440063  0.780417  0.520797
# 1    0.551855       0.177155 -2.136274   1.262768 -1.164898  1.075774
# 2    0.551855       0.470221  0.481977  -0.256757 -1.164898  1.095937
# 3   -0.516473       0.229917  0.429036   0.699536  0.680108 -1.792659
# 4   -0.847169       0.505839  0.585305   0.219079  0.500661  0.552466
# ..        ...            ...       ...        ...       ...       ...
# 108  0.896674       1.221058 -0.764830   0.612342  1.181766  2.888291
# 109 -0.785283       0.413812 -0.314216   1.331153 -1.164898 -1.792659
# 110  2.005377       2.762053  3.284171   2.046737  1.267024  0.901730
# 111 -0.965104       0.091108  0.429036  -0.980937  0.184531  0.520797
# 112  0.777795      -3.042740 -2.564970  -2.881033 -1.164898 -0.373793
#
#           NO3       PO4  Total Hardness  Ca (mg/L)  Mg (mg/L)  Na (mg/L)  \
# ...

# %%
m_val_ani_after_scaling = [fd[col].mean() for col in to_convert]
m_val_ani_after_scaling
# Out:
# [np.float64(-1.4737473778210044e-17),
#  np.float64(-3.1439944060181424e-17),
#  np.float64(3.929993007522678e-18),
#  np.float64(1.964996503761339e-17),
#  np.float64(1.964996503761339e-18),
#  np.float64(5.501990210531749e-17),
#  np.float64(-4.7159916090272136e-17),
#  np.float64(3.193119318612176e-17),
#  np.float64(3.53699370677041e-17),
#  np.float64(-5.894989511284017e-18),
#  np.float64(9.824982518806695e-18),
#  np.float64(7.07398741354082e-17),
#  np.float64(9.824982518806695e-18),
#  np.float64(-3.53699370677041e-17)]

# %%
sk_val_ani_after_scaling = {col: skew(fd[col].dropna()) for col in to_convert}
sk_val_ani_after_scaling
# Out:
# {'pH': np.float64(-0.00934785946878587),
#  'EC (µS/cm at)': np.float64(-0.007354756076323322),
#  'Ca (mg/L)': np.float64(0.024138047333033763),
#  'Cl (mg/L)': np.float64(-0.05822386344145005),
#  'F (mg/L)': np.float64(0.05760748455742084),
#  'Fe (ppm)': np.float64(0.07505534490600804),
#  'HCO3': np.float64(0.06226871386756835),
#  'K (mg/L)': np.float64(0.004415385860133235),
#  'Mg (mg/L)': np.float64(0.03146482964847309),
#  'NO3': np.float64(0.025307817284227048),
#  'Na (mg/L)': np.float64(-0.03707388932776324),
#  'PO4': np.float64(0.02114521188972193),
#  'SO4': np.float64(0.11077181333073921),
#  'Total Hardness': np.float64(0.07356082270747884)}

# %%
plt.figure()
sns.displot(sk_val_ani_after_scaling)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(sk_val_ani_after_scaling, fill=True)
plt.show()

# %% [markdown]
# Now the data is approximately symmetric or normal
# as the range is between  -0.5 and +0.5.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
fd[to_convert] = scaler.fit_transform(fd[to_convert])
fd
# Out:
#            pH  EC (µS/cm at)      HCO3  Cl (mg/L)  F (mg/L)       SO4  \
# 0   -1.179485      -0.147758  0.020462  -1.440063  0.780417  0.520797
# 1    0.551855       0.177155 -2.136274   1.262768 -1.164898  1.075774
# 2    0.551855       0.470221  0.481977  -0.256757 -1.164898  1.095937
# 3   -0.516473       0.229917  0.429036   0.699536  0.680108 -1.792659
# 4   -0.847169       0.505839  0.585305   0.219079  0.500661  0.552466
# ..        ...            ...       ...        ...       ...       ...
# 108  0.896674       1.221058 -0.764830   0.612342  1.181766  2.888291
# 109 -0.785283       0.413812 -0.314216   1.331153 -1.164898 -1.792659
# 110  2.005377       2.762053  3.284171   2.046737  1.267024  0.901730
# 111 -0.965104       0.091108  0.429036  -0.980937  0.184531  0.520797
# 112  0.777795      -3.042740 -2.564970  -2.881033 -1.164898 -0.373793
#
#           NO3       PO4  Total Hardness  Ca (mg/L)  Mg (mg/L)  Na (mg/L)  \
# ...

# %%
# from scipy.stats import zscore
# fd = fd[(np.abs(zscore(fd[to_convert])) < 3).all(axis=1)]  # Removes values beyond 3 std deviations
# fd
# Out:
#            pH  EC (µS/cm at)      HCO3  Cl (mg/L)  F (mg/L)       SO4  \
# 0   -1.179485      -0.147758  0.020462  -1.440063  0.780417  0.520797
# 1    0.551855       0.177155 -2.136274   1.262768 -1.164898  1.075774
# 2    0.551855       0.470221  0.481977  -0.256757 -1.164898  1.095937
# 3   -0.516473       0.229917  0.429036   0.699536  0.680108 -1.792659
# 4   -0.847169       0.505839  0.585305   0.219079  0.500661  0.552466
# ..        ...            ...       ...        ...       ...       ...
# 106  1.700111      -0.894374 -0.935734   0.069809 -1.164898 -1.792659
# 107 -0.516473      -1.590658 -1.451449  -0.256757  1.352677 -1.009911
# 108  0.896674       1.221058 -0.764830   0.612342  1.181766  2.888291
# 109 -0.785283       0.413812 -0.314216   1.331153 -1.164898 -1.792659
# 111 -0.965104       0.091108  0.429036  -0.980937  0.184531  0.520797
#
#           NO3       PO4  Total Hardness  Ca (mg/L)  Mg (mg/L)  Na (mg/L)  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(fd.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **Interpretation of Colors:**
# - 🔴 Dark Red (Close to +1) → Strong Positive Correlation
#
# Example: "Mg (mg/L)" and "Ca (mg/L)" (Correlation ≈ 0.93)
#
# This means that as one variable increases, the other also increases.
#
# - 🔵 Dark Blue (Close to -1) → Strong Negative Correlation
#
# Example: "pH" and "Total Hardness" (Correlation ≈ -0.17)
#
# This means that as one variable increases, the other decreases.
#
# - ⚪ Light Colors (Near 0) → Weak or No Correlation
#
# Example: "NO3" and "SO4" (Correlation ≈ 0.06)
#
# This suggests that these variables are not strongly related.

# %% [markdown]
# **1️⃣ Identify Highly Correlated Variables (🔴 > 0.8 or 🔵 < -0.8)**
# Highly positive correlations suggest redundancy (e.g., "Ca (mg/L)" and "Mg (mg/L)" with 0.93).
#
# Possible Action: Consider removing one of the strongly correlated features to avoid multicollinearity (if using regression models).
#
# **✅ Variables to consider for removal or combination:**
#
# "Ca (mg/L)" and "Mg (mg/L)"
#
# "EC (µS/cm at)" and "Total Hardness" (≈ 0.83)
#
# "Na (mg/L)" and "EC (µS/cm at)" (≈ 0.74)

# %%
# Load your dataset (Assuming 'df' is your cleaned data after normalization)
# df = pd.read_csv("your_data.csv")  # Uncomment if loading from a file

# Compute the correlation matrix
correlation_matrix = fd.corr().abs()  # Get absolute correlations

# Set threshold for high correlation (e.g., 0.8)
threshold = 0.8

# Find pairs of highly correlated variables
high_corr_pairs = np.where(correlation_matrix > threshold)
high_corr_pairs = [(correlation_matrix.index[i], correlation_matrix.columns[j]) 
                   for i, j in zip(*high_corr_pairs) if i != j]

# Convert list to a set to remove duplicates
unique_high_corr_vars = set([pair[1] for pair in high_corr_pairs])

# Drop one variable from each highly correlated pair
fd_reduced = fd.drop(columns=unique_high_corr_vars)

print(f"Removed variables due to high correlation: {unique_high_corr_vars}")
print(f"Shape before: {df.shape}, After: {fd_reduced.shape}")

# Save the cleaned dataset
# fd_reduced.to_csv("cleaned_data.csv", index=False)
fd_reduced
# Out:
# Removed variables due to high correlation: {'Total Hardness', 'HCO3', 'Mg (mg/L)', 'EC (µS/cm at)'}
# Shape before: (16776, 24), After: (109, 10)
#            pH  Cl (mg/L)  F (mg/L)       SO4       NO3       PO4  Ca (mg/L)  \
# 0   -1.179485  -1.440063  0.780417  0.520797  1.062270  0.145610  -1.160926
# 1    0.551855   1.262768 -1.164898  1.075774  1.216199 -0.162442   0.367608
# 2    0.551855  -0.256757 -1.164898  1.095937 -0.431273  0.424763   1.248730
# 3   -0.516473   0.699536  0.680108 -1.792659  0.041298  1.130644  -0.402076
# 4   -0.847169   0.219079  0.500661  0.552466  1.280300  0.145610   0.532575
# ..        ...        ...       ...       ...       ...       ...        ...
# 106  1.700111   0.069809 -1.164898 -1.792659  0.341748 -0.162442  -0.631955
# 107 -0.516473  -0.256757  1.352677 -1.009911  0.041298  0.679829  -1.831130
# 108  0.896674   0.612342  1.181766  2.888291  1.437772  0.424763  -0.631955
# ...

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)  # Reduce to 2 dimensions
X_pca = pca.fit_transform(fd_reduced)  # Transform dataset

# Plot first two principal components
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Reduced Data")
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(fd)  # without reducing according to the correlation

# Plot first two principal components
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Reduced Data")
plt.show()

# %%
# Check explained variance ratio
explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance)
print("Total Variance Explained:", sum(explained_variance))
# Out:
# Explained Variance Ratio: [0.30731269 0.15576419]
# Total Variance Explained: 0.4630768773756182

# %% [markdown]
# Since total variance is not above 85-90% (only 45% is retained). So we will n_components = 0.9 means keep 90% of variance.

# %%
pca = PCA(n_components=0.9)  #keep 90% variance
X_pca = pca.fit_transform(fd_reduced)  # Transform dataset of reduced dataset

# Plot first two principal components
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Reduced Data")
plt.show()

# %%
explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance)
print("Total Variance Explained:", sum(explained_variance))
# Out:
# Explained Variance Ratio: [0.22299115 0.16963742 0.12743427 0.11479701 0.09901873 0.09505204
#  0.06605408 0.05432732]
# Total Variance Explained: 0.9493120148081

# %% [markdown]
# Now, variance obtained is above 85-90% means PCA transformation retains most of the original dataset's information

# %% [markdown]
# **ANI cleaning is completed**

# %% [markdown]
# **Now continue with next state**

# %%
AP = AP.replace("-", np.nan)
AP
# Out:
# C:\Users\Eti Garg\AppData\Local\Temp\ipykernel_8908\3991439755.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   AP = AP.replace("-", np.nan)
#      S. No.              State    District           Location Longitude  \
# 113     114  Arunachal Pradesh   Changlang          Jairampur   96.0144
# 114     115  Arunachal Pradesh   Changlang            Namchik    95.972
# 115     116  Arunachal Pradesh   Changlang            Namphai   96.1086
# 116     117  Arunachal Pradesh   Changlang  Newlisan Kharsang   96.0418
# 117     118  Arunachal Pradesh  East Siang       Pasighat New   95.3358
# 118     119  Arunachal Pradesh  East Siang               Oyan   95.3183
# 119     120  Arunachal Pradesh  East Siang             Ruksin   95.2182
# ...

# %%
AP.isnull().sum()
# Out:
# S. No.             0
# State              0
# District           0
# Location           0
# Longitude          0
# Latitude           0
# Year               0
# pH                 0
# EC (µS/cm at)      0
# HCO3               0
# Cl (mg/L)          0
# F (mg/L)           0
# SO4                0
# NO3                0
# PO4               12
# Total Hardness     0
# Ca (mg/L)          0
# Mg (mg/L)          0
# Na (mg/L)          0
# K (mg/L)           0
# Fe (ppm)           0
# As (ppb)           0
# U (ppb)            0
# dtype: int64

# %%
AP=AP.drop("PO4", axis=1)
AP
# Out:
#      S. No.              State    District           Location Longitude  \
# 113     114  Arunachal Pradesh   Changlang          Jairampur   96.0144
# 114     115  Arunachal Pradesh   Changlang            Namchik    95.972
# 115     116  Arunachal Pradesh   Changlang            Namphai   96.1086
# 116     117  Arunachal Pradesh   Changlang  Newlisan Kharsang   96.0418
# 117     118  Arunachal Pradesh  East Siang       Pasighat New   95.3358
# 118     119  Arunachal Pradesh  East Siang               Oyan   95.3183
# 119     120  Arunachal Pradesh  East Siang             Ruksin   95.2182
# 120     121  Arunachal Pradesh       Lohit             Lathow   95.9098
# 121     122  Arunachal Pradesh   Papumpare      Banderedewa I   93.8258
# 122     123  Arunachal Pradesh       Tirap            Deomali   95.4628
# 123     124  Arunachal Pradesh       Tirap           Borduria   95.4131
# 124     125  Arunachal Pradesh       Tirap          Hukanjuri   95.4377
#
# ...

# %%
AP.isnull().sum()
# Out:
# S. No.            0
# State             0
# District          0
# Location          0
# Longitude         0
# Latitude          0
# Year              0
# pH                0
# EC (µS/cm at)     0
# HCO3              0
# Cl (mg/L)         0
# F (mg/L)          0
# SO4               0
# NO3               0
# Total Hardness    0
# Ca (mg/L)         0
# Mg (mg/L)         0
# Na (mg/L)         0
# K (mg/L)          0
# Fe (ppm)          0
# As (ppb)          0
# U (ppb)           0
# dtype: int64

# %%
AP_num_data = AP[["pH", "EC (µS/cm at)", "HCO3", "Cl (mg/L)", "F (mg/L)", "SO4", "NO3", "Total Hardness", "Ca (mg/L)", "Mg (mg/L)", "Na (mg/L)", "K (mg/L)", "Fe (ppm)",
"As (ppb)","U (ppb)"]]
AP_num_data
# Out:
#        pH EC (µS/cm at) HCO3 Cl (mg/L) F (mg/L) SO4 NO3 Total Hardness  \
# 113  7.29           265  165        23     0.08  21   0            160
# 114  7.29           279  165        40     0.07  17   0            155
# 115  7.26           261  177        10     0.06  18   0            150
# 116  7.24           260  159        23     0.06  18   0            150
# 117  7.99           466  232        27     0.07  31   2            230
# 118   7.9           469  238        36     0.06  38   3            225
# 119  7.83           465  214        36     0.05  22   2            220
# 120  7.29           271  165        23     0.05  18   0            165
# 121  7.78           204  147        17     0.03   6   5            130
# 122  7.74           216  140        17     0.03   6   7            155
# 123  7.68           212  147        17     0.03   8   8             95
# 124  7.73           212  147        10     0.03   6   7            125
#
# ...

# %%
plt.figure(figsize=(4,3))
sns.heatmap(AP_num_data.isnull())
# Out:
# <Axes: >

# %%
fd1 = pd.DataFrame(AP_num_data)
to_convert_ap = [
    "pH", "EC (µS/cm at)", "Ca (mg/L)", "Cl (mg/L)", "F (mg/L)", "Fe (ppm)", "HCO3", "K (mg/L)",
    "Mg (mg/L)", "NO3", "Na (mg/L)", "SO4", "Total Hardness", "As (ppb)","U (ppb)"
]
for col1 in to_convert_ap:
    fd1[col1] = pd.to_numeric(fd1[col1], errors="coerce")
print(fd1.dtypes)
# Out:
# pH                float64
# EC (µS/cm at)       int64
# HCO3                int64
# Cl (mg/L)           int64
# F (mg/L)          float64
# SO4                 int64
# NO3                 int64
# Total Hardness      int64
# Ca (mg/L)           int64
# Mg (mg/L)           int64
# Na (mg/L)           int64
# K (mg/L)            int64
# Fe (ppm)          float64
# As (ppb)          float64
# U (ppb)           float64
# dtype: object

# %%
mean_values_ap= [fd1[col1].mean() for col1 in to_convert_ap]
mean_values_ap
# Out:
# [np.float64(7.585),
#  np.float64(298.3333333333333),
#  np.float64(41.0),
#  np.float64(23.25),
#  np.float64(0.05166666666666667),
#  np.float64(0.8891666666666667),
#  np.float64(174.66666666666666),
#  np.float64(12.75),
#  np.float64(14.75),
#  np.float64(2.8333333333333335),
#  np.float64(12.083333333333334),
#  np.float64(17.416666666666668),
#  np.float64(163.33333333333334),
#  np.float64(0.31333333333333335),
#  np.float64(0.03916666666666666)]

# %%
skewness_values_ap = {col1: skew(fd1[col1].dropna()) for col1 in to_convert_ap}
skewness_values_ap
# Out:
# {'pH': np.float64(-0.10113103798252267),
#  'EC (µS/cm at)': np.float64(0.9464577205263139),
#  'Ca (mg/L)': np.float64(0.7024414737848987),
#  'Cl (mg/L)': np.float64(0.33894512917027797),
#  'F (mg/L)': np.float64(-0.06324444320859578),
#  'Fe (ppm)': np.float64(1.4087292798595932),
#  'HCO3': np.float64(0.9286371934676088),
#  'K (mg/L)': np.float64(1.1523559123149727),
#  'Mg (mg/L)': np.float64(-0.9897853574474657),
#  'NO3': np.float64(0.5515914733148766),
#  'Na (mg/L)': np.float64(0.6005672608045548),
#  'SO4': np.float64(0.5588468420093339),
#  'Total Hardness': np.float64(0.3828202936587556),
#  'As (ppb)': np.float64(1.7478728593773432),
#  'U (ppb)': np.float64(-0.09464051798689141)}

# %%
plt.figure()
sns.displot(fd1)
plt.show()

# %%
sns.kdeplot(skewness_values_ap, fill=True)
plt.show()

# %%
from scipy.stats import skew

print("Skewness:", skew(fd1))
# Out:
# Skewness: [-0.10113104  0.94645772  0.92863719  0.33894513 -0.06324444  0.55884684
#   0.55159147  0.38282029  0.70244147 -0.98978536  0.60056726  1.15235591
#   1.40872928  1.74787286 -0.09464052]

# %% [markdown]
# Skewness range is between -0.5 to 0.5

# %%
UP = UP.replace("-", np.nan)
UP
# Out:
#       S. No.          State  District                     Location Longitude  \
# 7559    7560  Uttar Pradesh      Agra                 Block Office   77.7462
# 7560    7561  Uttar Pradesh      Agra                    Raunakata   77.8734
# 7561    7562  Uttar Pradesh      Agra  City(Sai Ki Takia Crossing)   78.0095
# 7562    7563  Uttar Pradesh      Agra                 Block Office   77.8857
# 7563    7564  Uttar Pradesh      Agra                Agra-Bah Road   78.4565
# ...      ...            ...       ...                          ...       ...
# 8941    8942  Uttar Pradesh  Varanasi                    Nai Sarak   83.0048
# 8942    8943  Uttar Pradesh  Varanasi                  Nanak Nagar   82.9899
# 8943    8944  Uttar Pradesh  Varanasi                      Shivpur   82.9456
# 8944    8945  Uttar Pradesh  Varanasi                       Singra   82.9835
# 8945    8946  Uttar Pradesh  Varanasi              Srinagar Colony   82.0056
#
# ...

# %%
UP.isnull().sum()
# Out:
# S. No.             0
# State              0
# District           0
# Location          25
# Longitude          0
# Latitude           0
# Year               0
# pH                 0
# EC (µS/cm at)      0
# HCO3               0
# Cl (mg/L)          0
# F (mg/L)           0
# SO4                0
# NO3                0
# PO4               64
# Total Hardness     0
# Ca (mg/L)          0
# Mg (mg/L)          0
# Na (mg/L)          0
# K (mg/L)           0
# Fe (ppm)           1
# As (ppb)           1
# U (ppb)            1
# dtype: int64

# %%
UP=UP.drop("PO4", axis=1)
UP
# Out:
#       S. No.          State  District                     Location Longitude  \
# 7559    7560  Uttar Pradesh      Agra                 Block Office   77.7462
# 7560    7561  Uttar Pradesh      Agra                    Raunakata   77.8734
# 7561    7562  Uttar Pradesh      Agra  City(Sai Ki Takia Crossing)   78.0095
# 7562    7563  Uttar Pradesh      Agra                 Block Office   77.8857
# 7563    7564  Uttar Pradesh      Agra                Agra-Bah Road   78.4565
# ...      ...            ...       ...                          ...       ...
# 8941    8942  Uttar Pradesh  Varanasi                    Nai Sarak   83.0048
# 8942    8943  Uttar Pradesh  Varanasi                  Nanak Nagar   82.9899
# 8943    8944  Uttar Pradesh  Varanasi                      Shivpur   82.9456
# 8944    8945  Uttar Pradesh  Varanasi                       Singra   82.9835
# 8945    8946  Uttar Pradesh  Varanasi              Srinagar Colony   82.0056
#
# ...

# %%
UP.isnull().sum()
# Out:
# S. No.             0
# State              0
# District           0
# Location          25
# Longitude          0
# Latitude           0
# Year               0
# pH                 0
# EC (µS/cm at)      0
# HCO3               0
# Cl (mg/L)          0
# F (mg/L)           0
# SO4                0
# NO3                0
# Total Hardness     0
# Ca (mg/L)          0
# Mg (mg/L)          0
# Na (mg/L)          0
# K (mg/L)           0
# Fe (ppm)           1
# As (ppb)           1
# U (ppb)            1
# dtype: int64

# %%
UP_num_data = UP[["pH", "EC (µS/cm at)", "HCO3", "Cl (mg/L)", 
"F (mg/L)", 
"SO4", 
"NO3",  
"Total Hardness", 
"Ca (mg/L)",
"Mg (mg/L)", 
"Na (mg/L)",
"K (mg/L)", 
"Fe (ppm)","As (ppb)","U (ppb)"]]
UP_num_data
# Out:
#         pH EC (µS/cm at) HCO3 Cl (mg/L) F (mg/L)   SO4  NO3 Total Hardness  \
# 7559  8.14          5850  500      1594     1.72   454   18           1390
# 7560     8          4923  488       760      0.7  1091   37            790
# 7561   8.2          1520  805        50     0.48    38   13            310
# 7562  8.15          1051  537        57        1    43   11            420
# 7563  7.72           972  268        99     0.92    42  104            295
# ...    ...           ...  ...       ...      ...   ...  ...            ...
# 8941  8.07           765  293        71      0.7    37    0            250
# 8942  7.85           840  366        50     0.95    39    0            300
# 8943  7.87           578  305        28     0.22     0   10            240
# 8944   7.6           778  305        57     0.64    42   14            270
# 8945  7.79           558  268        21      0.9    10   15            240
#
# ...

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean')

# %%
numerical_cols = UP.select_dtypes(include=['number']).columns

# %%
UP[numerical_cols] = imputer.fit_transform(UP[numerical_cols])

# %%
UP.isnull().sum()
# Out:
# S. No.             0
# State              0
# District           0
# Location          25
# Longitude          0
# Latitude           0
# Year               0
# pH                 0
# EC (µS/cm at)      0
# HCO3               0
# Cl (mg/L)          0
# F (mg/L)           0
# SO4                0
# NO3                0
# Total Hardness     0
# Ca (mg/L)          0
# Mg (mg/L)          0
# Na (mg/L)          0
# K (mg/L)           0
# Fe (ppm)           1
# As (ppb)           1
# U (ppb)            1
# dtype: int64
